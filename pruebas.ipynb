# %%
import pandas as pd

# Importar el archivo CSV
df = pd.read_csv("data/raw_datasets/METLIN-CCS-Lipids_descriptors.csv")

# Mostrar solo la columna "nStructures"
print(df['nStructures'])
# Out:
# La ejecución de celdas con 'base (Python 3.13.5)' requiere el paquete ipykernel.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Crear un entorno de Python</a> con los paquetes necesarios.
#
# O instale "ipykernel" mediante el comando: "conda install -n base ipykernel --update-deps --force-reinstall"
